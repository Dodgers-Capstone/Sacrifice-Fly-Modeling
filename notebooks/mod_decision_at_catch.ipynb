# %%
import polars as pl
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
on_base = pl.scan_parquet("../data/throw_home_runner_on_third_wide_sprint_arm.parquet")
on_base.collect_schema()
# Out:
# Schema([('game_id', Int64),
#         ('year', Int64),
#         ('game_date', Date),
#         ('pa_id', String),
#         ('play_id', String),
#         ('pitch_id', String),
#         ('is_advance', Boolean),
#         ('is_out', Boolean),
#         ('is_stay', Boolean),
#         ('fielder_credit_id', Int64),
#         ('event_type', String),
#         ('fielder_position', Int64),
#         ('fielder_mlb_person_id', Int64),
#         ('fielder_name', String),
#         ('fielder_credit_type', String),
#         ('runner_name', String),
#         ('fielder_team', String),
#         ('runner_team', String),
#         ('inning', Int64),
#         ('inning_top', Boolean),
#         ('pre_runner_1b', Boolean),
#         ('pre_runner_2b', Boolean),
#         ('pre_runner_3b', Boolean),
#         ('pre_outs', Int64),
#         ('post_runner_1b', Boolean),
#         ('post_runner_2b', Boolean),
#         ('post_runner_3b', Boolean),
#         ('post_outs', Int64),
#         ('start_time', Float64),
#         ('start_pos_x', Float64),
#         ('start_pos_y', Float64),
#         ('start_pos_z', Float64),
#         ('start_vel_x', Float64),
#         ('start_vel_y', Float64),
#         ('start_vel_z', Float64),
#         ('start_speed', Float64),
#         ('end_time', Float64),
#         ('end_pos_x', Float64),
#         ('end_pos_y', Float64),
#         ('end_pos_z', Float64),
#         ('end_vel_x', Float64),
#         ('end_vel_y', Float64),
#         ('end_vel_z', Float64),
#         ('end_speed', Float64),
#         ('landing_time', Float64),
#         ('landing_pos_x', Float64),
#         ('landing_pos_y', Float64),
#         ('landing_pos_z', Float64),
#         ('arm_strength', Float64),
#         ('distance_covered', Float64),
#         ('total_distance_covered', Float64),
#         ('throw_distance', Float64),
#         ('angle_to_ball_landing', Float64),
#         ('angle_to_ball_caught', Float64),
#         ('lead_distance', Float64),
#         ('sprint_speed_runner', Float64),
#         ('t_3b_to_home', Float64),
#         ('exit_speed', Float64),
#         ('vert_exit_angle', Float64),
#         ('horz_exit_angle', Float64),
#         ('exit_spin_rate', Float64),
#         ('exit_spin_axis', Float64),
#         ('landing_bearing', Float64),
#         ('landing_distance', Float64),
#         ('score_differential', Int64),
#         ('hang_time', Float64),
#         ('url', String),
#         ('pos_code_LF', String),
#         ('pos_code_CF', String),
#         ('pos_code_RF', String),
#         ('pos_code_R3', String),
#         ('pos_id_LF', Float64),
#         ('pos_id_CF', Float64),
#         ('pos_id_RF', Float64),
#         ('pos_id_R3', Float64),
#         ('mlb_person_id_LF', Int64),
#         ('mlb_person_id_CF', Int64),
#         ('mlb_person_id_RF', Int64),
#         ('mlb_person_id_R3', Int64),
#         ('at_pitch_x_LF', Float64),
#         ('at_pitch_x_CF', Float64),
#         ('at_pitch_x_RF', Float64),
#         ('at_pitch_x_R3', Float64),
#         ('at_pitch_y_LF', Float64),
#         ('at_pitch_y_CF', Float64),
#         ('at_pitch_y_RF', Float64),
#         ('at_pitch_y_R3', Float64),
#         ('at_zone_x_LF', Float64),
#         ('at_zone_x_CF', Float64),
#         ('at_zone_x_RF', Float64),
#         ('at_zone_x_R3', Float64),
#         ('at_zone_y_LF', Float64),
#         ('at_zone_y_CF', Float64),
#         ('at_zone_y_RF', Float64),
#         ('at_zone_y_R3', Float64),
#         ('at_landing_x_LF', Float64),
#         ('at_landing_x_CF', Float64),
#         ('at_landing_x_RF', Float64),
#         ('at_landing_x_R3', Float64),
#         ('at_landing_y_LF', Float64),
#         ('at_landing_y_CF', Float64),
#         ('at_landing_y_RF', Float64),
#         ('at_landing_y_R3', Float64),
#         ('at_fielded_x_LF', Float64),
#         ('at_fielded_x_CF', Float64),
#         ('at_fielded_x_RF', Float64),
#         ('at_fielded_x_R3', Float64),
#         ('at_fielded_y_LF', Float64),
#         ('at_fielded_y_CF', Float64),
#         ('at_fielded_y_RF', Float64),
#         ('at_fielded_y_R3', Float64),
#         ('at_throw_1_x_LF', Float64),
#         ('at_throw_1_x_CF', Float64),
#         ('at_throw_1_x_RF', Float64),
#         ('at_throw_1_x_R3', Float64),
#         ('at_throw_1_y_LF', Float64),
#         ('at_throw_1_y_CF', Float64),
#         ('at_throw_1_y_RF', Float64),
#         ('at_throw_1_y_R3', Float64),
#         ('bat_side_mlb_person_id_R3', String),
#         ('seconds_since_hit_000_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_005_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_010_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_015_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_020_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_025_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_030_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_035_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_040_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_045_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_050_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_055_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_060_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_065_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_070_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_075_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_080_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_085_mlb_person_id_R3', Float64),
#         ('seconds_since_hit_090_mlb_person_id_R3', Float64),
#         ('total_throws_mlb_person_id_LF', Int64),
#         ('max_arm_strength_mlb_person_id_LF', Float64),
#         ('arm_overall_mlb_person_id_LF', Float64),
#         ('total_throws_mlb_person_id_CF', Int64),
#         ('max_arm_strength_mlb_person_id_CF', Float64),
#         ('arm_overall_mlb_person_id_CF', Float64),
#         ('total_throws_mlb_person_id_RF', Int64),
#         ('max_arm_strength_mlb_person_id_RF', Float64),
#         ('arm_overall_mlb_person_id_RF', Float64),
#         ('total_throws_fielder_mlb_person_id', Int64),
#         ('max_arm_strength_fielder_mlb_person_id', Float64),
#         ('arm_overall_fielder_mlb_person_id', Float64),
#         ('at_zone_x_fielder', Float64),
#         ('at_zone_y_fielder', Float64),
#         ('at_fielded_x_fielder', Float64),
#         ('at_fielded_y_fielder', Float64),
#         ('distance_catch_to_home', Float64),
#         ('distance_catch_to_third', Float64),
#         ('distance_catch_to_second', Float64),
#         ('distance_catch_to_first', Float64),
#         ('distance_traveled_fielder', Float64),
#         ('distance_traveled_LF', Float64),
#         ('distance_traveled_CF', Float64),
#         ('distance_traveled_RF', Float64),
#         ('distance_traveled_all_fielders', Float64),
#         ('distance_to_home_diff', Float64),
#         ('is_successful', Boolean)])

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class prior_to_catch(BaseEstimator, TransformerMixin):

    def fit(self, X, y = None):
        return self
    
    def transform(self, X):
        return X.drop([])
